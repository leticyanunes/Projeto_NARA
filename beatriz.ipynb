# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
sns.set(style='whitegrid', palette='pastel')
plt.rcParams['figure.figsize'] = (10, 5)

# %%
clientes = pd.read_csv('clientes.csv', sep=",")
clientes
# Out:
#      ID_Cliente                       Nome  Idade Sexo          Cidade Estado  \
# 0             1                Cauã Guerra     56    M       São Paulo     RS
# 1             2               Luísa Vargas     69    M  Rio de Janeiro     RJ
# 2             3           Larissa Monteiro     46    M    Porto Alegre     PR
# 3             4            Larissa Ribeiro     32    F    Porto Alegre     PR
# 4             5              Otávio Castro     60    M  Belo Horizonte     RJ
# ..          ...                        ...    ...  ...             ...    ...
# 995         996                 Yuri Pinto     60    F        Curitiba     PR
# 996         997    Srta. Anna Liz Mendonça     64    M       São Paulo     SP
# 997         998               Liz da Cunha     62    F        Curitiba     PR
# 998         999  Maria Cecília Vasconcelos     35    M    Porto Alegre     MG
# 999        1000           Kamilly Teixeira     55    M  Belo Horizonte     RS
#
#     Canal_Aquisicao
# ...

# %%
produtos = pd.read_csv('produtos.csv',  sep=",")
produtos
# Out:
#     ID_Produto                   Nome_Produto         Categoria    Preco  \
# 0            1           Máquina de Lavar 8kg  Eletrodomésticos  1632.61
# 1            2  Smartphone Samsung Galaxy S21  Eletrodomésticos  3306.28
# 2            3         Notebook Dell Inspiron  Eletrodomésticos  1236.89
# 3            4                      TV LG 50"       Eletrônicos   170.47
# 4            5  Geladeira Brastemp Frost Free  Eletrodomésticos  3845.33
# ..         ...                            ...               ...      ...
# 94          95                Roteador D-Link            Móveis  1742.87
# 95          96              Smartwatch Huawei       Informática   428.38
# 96          97       Máquina de Costura Elgin            Móveis  4879.18
# 97          98             Ventilador Mondial            Móveis  4103.17
# 98          99             Cooktop Electrolux            Móveis  4277.48
#
#          Marca
# 0          NaN
# 1      Samsung
# 2         Dell
# 3           LG
# ...

# %%
produto_novo = pd.read_csv('produtos_tratados.csv')
produto_novo
# Out:
#     ID_Produto                   Nome_Produto         Categoria    Preco  \
# 0            1           Máquina de Lavar 8kg  Eletrodomésticos  1632.61
# 1            2  Smartphone Samsung Galaxy S21  Eletrodomésticos  3306.28
# 2            3         Notebook Dell Inspiron  Eletrodomésticos  1236.89
# 3            4                      TV LG 50"       Eletrônicos   170.47
# 4            5  Geladeira Brastemp Frost Free  Eletrodomésticos  3845.33
# ..         ...                            ...               ...      ...
# 94          95                Roteador D-Link            Móveis  1742.87
# 95          96              Smartwatch Huawei       Informática   428.38
# 96          97       Máquina de Costura Elgin            Móveis  4879.18
# 97          98             Ventilador Mondial            Móveis  4103.17
# 98          99             Cooktop Electrolux            Móveis  4277.48
#
#          Marca
# 0          NaN
# 1      Samsung
# 2         Dell
# 3           LG
# ...

# %%
novo = pd.merge(produtos, produto_novo, left_on='ID_Produto', right_on='ID_Produto',
how='inner')
novo
# Out:
#     ID_Produto                 Nome_Produto_x       Categoria_x  Preco_x  \
# 0            1           Máquina de Lavar 8kg  Eletrodomésticos  1632.61
# 1            2  Smartphone Samsung Galaxy S21  Eletrodomésticos  3306.28
# 2            3         Notebook Dell Inspiron  Eletrodomésticos  1236.89
# 3            4                      TV LG 50"       Eletrônicos   170.47
# 4            5  Geladeira Brastemp Frost Free  Eletrodomésticos  3845.33
# ..         ...                            ...               ...      ...
# 94          95                Roteador D-Link            Móveis  1742.87
# 95          96              Smartwatch Huawei       Informática   428.38
# 96          97       Máquina de Costura Elgin            Móveis  4879.18
# 97          98             Ventilador Mondial            Móveis  4103.17
# 98          99             Cooktop Electrolux            Móveis  4277.48
#
#        Marca_x                 Nome_Produto_y       Categoria_y  Preco_y  \
# ...

# %%
deletar_duplicata = novo.drop(columns = 'Marca_x')
deletar_duplicata
# Out:
#     ID_Produto                 Nome_Produto_x       Categoria_x  Preco_x  \
# 0            1           Máquina de Lavar 8kg  Eletrodomésticos  1632.61
# 1            2  Smartphone Samsung Galaxy S21  Eletrodomésticos  3306.28
# 2            3         Notebook Dell Inspiron  Eletrodomésticos  1236.89
# 3            4                      TV LG 50"       Eletrônicos   170.47
# 4            5  Geladeira Brastemp Frost Free  Eletrodomésticos  3845.33
# ..         ...                            ...               ...      ...
# 94          95                Roteador D-Link            Móveis  1742.87
# 95          96              Smartwatch Huawei       Informática   428.38
# 96          97       Máquina de Costura Elgin            Móveis  4879.18
# 97          98             Ventilador Mondial            Móveis  4103.17
# 98          99             Cooktop Electrolux            Móveis  4277.48
#
#                    Nome_Produto_y       Categoria_y  Preco_y     Marca_y
# ...

# %%
vendas = pd.read_csv('vendas.csv', sep=",")
vendas
# Out:
#        ID_Venda  ID_Cliente  ID_Produto        Data  Quantidade        Canal  \
# 0             1         350          45  2022-09-23           4       Online
# 1             2         925          68  2024-02-09           1  Loja Física
# 2             3         915          75  2022-09-11           4       Online
# 3             4         494          47  2024-05-10           4  Loja Física
# 4             5         523          79  2023-10-15           4  Loja Física
# ...         ...         ...         ...         ...         ...          ...
# 19995     19996         179          88  2024-04-29           1  Loja Física
# 19996     19997         702           8  2023-05-01           2       Online
# 19997     19998         163          47  2022-01-11           1       Online
# 19998     19999         593           6  2022-11-22           2       Online
# 19999     20000         170           7  2023-03-03           1  Loja Física
#
#        Valor_Total
# 0          5795.64
# ...

# %%
avaliacoes = pd.read_csv('avaliacoes.csv', sep=",")
avaliacoes
# Out:
#      ID_Cliente  ID_Produto  Nota Data_Avaliacao Comentario
# 0            99          24     3     2022-11-26       Ruim
# 1            26          16     4     2023-04-22  Excelente
# 2             8          17     2     2023-03-29    Péssimo
# 3           100          26     1     2023-03-29    Regular
# 4            94          27     5     2023-11-23       Ruim
# ..          ...         ...   ...            ...        ...
# 295          15          30     4     2024-01-03        Bom
# 296          10          11     3     2022-07-23       Ruim
# 297          88          18     3     2022-03-19        Bom
# 298          42          29     5     2023-08-30    Regular
# 299          72          24     1     2023-12-09    Péssimo
#
# [300 rows x 5 columns]

# %%
campanhas = pd.read_csv('campanhas_corrigido.csv', sep=",")
campanhas
# Out:
#     ID_Campanha      Canal Data_Inicio    Data_Fim Tipo_Campanha     Custo
# 0            12  Impressos  2022-01-01  2022-03-09      Desconto  21049.65
# 1             2  Impressos  2022-03-10  2022-05-16    Fidelidade   2589.43
# 2             8         TV  2022-05-17  2022-07-23    Lançamento   8487.03
# 3            17     Online  2022-07-24  2022-09-29      Desconto   5034.61
# 4            11         TV  2022-09-30  2022-12-06      Desconto   8914.11
# 5             3         TV  2022-12-07  2023-02-12    Lançamento   6288.94
# 6            19      Rádio  2023-02-13  2023-04-21      Desconto  32261.36
# 7             7      Rádio  2023-04-22  2023-06-28    Lançamento  19696.01
# 8            14      Rádio  2023-06-29  2023-09-04    Lançamento   1100.43
# 9             5      Rádio  2023-09-05  2023-11-11    Fidelidade  38884.08
# 10           18     Online  2023-11-12  2024-01-18    Lançamento  14083.34
# ...

# %%
atendimentos = pd.read_csv('atendimentos.csv', sep=',')
atendimentos
# Out:
#      ID_Atendimento  ID_Cliente        Tipo        Data  Tempo_Resposta  \
# 0                 1          52      Elogio  2023-10-17           14.79
# 1                 2          93      Dúvida  2022-04-25            0.33
# 2                 3          15  Reclamação  2022-01-26           70.74
# 3                 4          72      Elogio  2024-01-30           14.35
# 4                 5          61  Reclamação  2022-10-09           11.54
# ..              ...         ...         ...         ...             ...
# 296             297           9  Reclamação  2023-03-25           12.31
# 297             298          99      Dúvida  2024-07-10            4.33
# 298             299          19  Reclamação  2023-06-14            1.96
# 299             300          48      Elogio  2023-04-08          138.04
# 300             301          80      Elogio  2022-05-04           11.67
#
#      Nota_Satisfacao
# 0                  2
# 1                  4
# 2                  1
# ...

# %%
vendas1 = pd.read_csv('venda 1.csv', sep=",")
vendas1
# Out:
#      ID_Venda  ID_Cliente  ID_Produto                 Data  Quantidade  \
# 0       19200          57          56  2025-05-25 00:00:00           2
# 1       19201         183          12  2025-07-12 00:00:00           1
# 2       19202         935          59  2024-10-18 00:00:00           4
# 3       19203         597          67  2025-08-30 00:00:00           4
# 4       19204         892          71  2025-01-14 00:00:00           2
# ..        ...         ...         ...                  ...         ...
# 995     20195         404          73  2024-12-19 00:00:00           4
# 996     20196         184          21  2024-10-12 00:00:00           2
# 997     20197          33          90  2024-12-06 00:00:00           1
# 998     20198          13          62  2025-05-10 00:00:00           3
# 999     20199          14           9  2025-03-08 00:00:00           3
#
#            Canal  Valor_Total
# 0    Loja Física       827501
# 1         Online       316061
# ...

# %%
vendas2 = pd.read_csv('venda 2.csv', sep=",")
vendas2
# Out:
#      ID_Venda  ID_Cliente  ID_Produto                 Data  Quantidade  \
# 0       20200         115          77  2025-05-15 00:00:00           3
# 1       20201         818          53  2025-01-14 00:00:00           3
# 2       20202         568          94  2025-04-04 00:00:00           4
# 3       20203         175          42  2025-03-17 00:00:00           3
# 4       20204         332          19  2025-02-11 00:00:00           4
# ..        ...         ...         ...                  ...         ...
# 995     21195         900          36  2025-06-17 00:00:00           2
# 996     21196         218           4  2025-02-04 00:00:00           4
# 997     21197         925          54  2024-12-11 00:00:00           2
# 998     21198         630          57  2024-11-24 00:00:00           2
# 999     21199         365          21  2025-06-22 00:00:00           3
#
#            Canal  Valor_Total
# 0         Online      1385874
# 1    Loja Física      1401033
# ...

# %%
vendas3 = pd.read_csv('venda 3.csv', sep=",")
vendas3
# Out:
#       ID_Venda  ID_Cliente  ID_Produto                 Data  Quantidade  \
# 0        21200         903          55  2025-02-07 00:00:00           2
# 1        21201         834           3  2024-10-28 00:00:00           1
# 2        21202         531          84  2025-05-08 00:00:00           4
# 3        21203         428          98  2025-03-14 00:00:00           2
# 4        21204         928           6  2024-12-04 00:00:00           4
# ...        ...         ...         ...                  ...         ...
# 1995     23195          99          68  2024-11-06 00:00:00           2
# 1996     23196         225          90  2024-10-14 00:00:00           2
# 1997     23197         974          15  2024-12-29 00:00:00           4
# 1998     23198         269          44  2025-06-13 00:00:00           3
# 1999     23199          54          23  2024-12-02 00:00:00           2
#
#             Canal  Valor_Total
# 0          Online        38762
# 1          Online       132302
# ...

# %%
df_vendas = pd.concat([vendas, vendas1, vendas2, vendas3], ignore_index=True)
df_vendas
# Out:
#        ID_Venda  ID_Cliente  ID_Produto                 Data  Quantidade  \
# 0             1         350          45           2022-09-23           4
# 1             2         925          68           2024-02-09           1
# 2             3         915          75           2022-09-11           4
# 3             4         494          47           2024-05-10           4
# 4             5         523          79           2023-10-15           4
# ...         ...         ...         ...                  ...         ...
# 23995     23195          99          68  2024-11-06 00:00:00           2
# 23996     23196         225          90  2024-10-14 00:00:00           2
# 23997     23197         974          15  2024-12-29 00:00:00           4
# 23998     23198         269          44  2025-06-13 00:00:00           3
# 23999     23199          54          23  2024-12-02 00:00:00           2
#
#              Canal  Valor_Total
# 0           Online      5795.64
# ...

# %%
df_vendas['Data'] = pd.to_datetime(df_vendas['Data'], errors='coerce')
df_vendas
# Out:
#        ID_Venda  ID_Cliente  ID_Produto       Data  Quantidade        Canal  \
# 0             1         350          45 2022-09-23           4       Online
# 1             2         925          68 2024-02-09           1  Loja Física
# 2             3         915          75 2022-09-11           4       Online
# 3             4         494          47 2024-05-10           4  Loja Física
# 4             5         523          79 2023-10-15           4  Loja Física
# ...         ...         ...         ...        ...         ...          ...
# 23995     23195          99          68        NaT           2       Online
# 23996     23196         225          90        NaT           2  Loja Física
# 23997     23197         974          15        NaT           4  Loja Física
# 23998     23198         269          44        NaT           3  Loja Física
# 23999     23199          54          23        NaT           2       Online
#
#        Valor_Total
# 0          5795.64
# ...

# %%
for nome, df in [("Clientes", clientes), ("Produtos", produtos), ("Vendas", df_vendas),
                 ("Avaliações", avaliacoes), ("Campanhas", campanhas), ("Atendimentos", atendimentos)]:
    print(f"\n--- {nome} ---")
    print(df.info())
    print(df.isnull().sum())
# Out:
# --- Clientes ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID_Cliente       1000 non-null   int64
#  1   Nome             1000 non-null   object
#  2   Idade            1000 non-null   int64
#  3   Sexo             1000 non-null   object
#  4   Cidade           1000 non-null   object
#  5   Estado           1000 non-null   object
#  6   Canal_Aquisicao  1000 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB
# None
# ID_Cliente         0
# Nome               0
# Idade              0
# Sexo               0
# Cidade             0
# Estado             0
# Canal_Aquisicao    0
# dtype: int64
#
# --- Produtos ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ...

# %%
clientes.drop_duplicates(subset=['ID_Cliente'], inplace=True)
produtos.drop_duplicates(subset=['ID_Produto'], inplace=True)
df_vendas = df_vendas.dropna(subset=['Data'])
avaliacoes.dropna(subset=['ID_Cliente', 'ID_Produto', 'Nota'], inplace=True)

# %%
clientes['Faixa_Etaria'] = np.where(clientes['Idade'] < 26, 'Jovem',
                                    np.where(clientes['Idade'] > 65, 'Idoso', 'Adulto'))

tabela_final = df_vendas.merge(produtos, on='ID_Produto', how='left')
tabela_final = tabela_final.merge(clientes, on='ID_Cliente', how='left')


tabela_final["Valor_Total"] = tabela_final["Quantidade"] * tabela_final["Preco"]

tabela_final["Faixa_Etaria"] = np.where(tabela_final["Idade"] < 26, "Jovem",
                                       np.where(tabela_final["Idade"] > 65, "Idoso", "Adulto"))


perfil = tabela_final.groupby("Faixa_Etaria")["Valor_Total"].sum().reset_index()


total = perfil["Valor_Total"].sum()
perfil["Percentual"] = (perfil["Valor_Total"] / total * 100).round(2)

print("\n--- Valor Total de Compras por Faixa Etária ---")
print(perfil)


plt.pie(
    perfil["Valor_Total"],
    labels=perfil["Faixa_Etaria"],
    autopct="%1.1f%%",
    startangle=90
)
plt.title("Valor Total de Compras por Faixa Etária")
plt.show()
# Out:
# --- Valor Total de Compras por Faixa Etária ---
#   Faixa_Etaria   Valor_Total  Percentual
# 0       Adulto  1.088033e+08       75.59
# 1        Idoso  1.202119e+07        8.35
# 2        Jovem  2.312270e+07       16.06

# %%
produtos['Preco'].describe()
sns.boxplot(x=produtos['Preco'])
plt.title("Dispersão de Preços dos Produtos")
plt.show()

# %%
precos_array = produtos['Preco'].dropna().values


media = np.mean(precos_array)
mediana = np.median(precos_array)


q1 = np.percentile(precos_array, 25)
q2 = np.percentile(precos_array, 50)
q3 = np.percentile(precos_array, 75)
iqr = q3 - q1
limite_inferior = q1 - 1.5 * iqr
limite_superior = q3 + 1.5 * iqr


variancia = np.var(precos_array)
desvio_padrao = np.std(precos_array)
coeficiente_variacao = (desvio_padrao / media) * 100
distancia_variancia = (variancia / (media ** 2)) * 100
distancia = (media - mediana) / mediana


print("\n--- Estatísticas Descritivas dos Preços ---")
print(f"Média: {media:.2f}")
print(f"Mediana: {mediana:.2f}")
print(f"Distância entre média e mediana: {distancia * 100:.2f}%")
print(f"Primeiro quartil (Q1): {q1:.2f}")
print(f"Segundo quartil (Q2 - Mediana): {q2:.2f}")
print(f"Terceiro quartil (Q3): {q3:.2f}")
print(f"Limite inferior: {limite_inferior:.2f}")
print(f"Limite superior: {limite_superior:.2f}")
print("\nVariância:", round(variancia, 2))
print("Desvio padrão:", round(desvio_padrao, 2))
print("Coeficiente de variação:", round(coeficiente_variacao, 2), "%")
print("Distância da variância em relação à média:", round(distancia_variancia, 2), "%")
# Out:
# --- Estatísticas Descritivas dos Preços ---
# Média: 2850.39
# Mediana: 3087.52
# Distância entre média e mediana: -7.68%
# Primeiro quartil (Q1): 1759.11
# Segundo quartil (Q2 - Mediana): 3087.52
# Terceiro quartil (Q3): 4033.36
# Limite inferior: -1652.27
# Limite superior: 7444.73
#
# Variância: 1965680.38
# Desvio padrão: 1402.03
# Coeficiente de variação: 49.19 %
# Distância da variância em relação à média: 24.19 %

# %%
df_vendas.loc[:,'Data'] = pd.to_datetime(df_vendas['Data'], format='%Y-%m-%d', errors='coerce')
df_vendas
# Out:
#        ID_Venda  ID_Cliente  ID_Produto       Data  Quantidade        Canal  \
# 0             1         350          45 2022-09-23           4       Online
# 1             2         925          68 2024-02-09           1  Loja Física
# 2             3         915          75 2022-09-11           4       Online
# 3             4         494          47 2024-05-10           4  Loja Física
# 4             5         523          79 2023-10-15           4  Loja Física
# ...         ...         ...         ...        ...         ...          ...
# 19995     19996         179          88 2024-04-29           1  Loja Física
# 19996     19997         702           8 2023-05-01           2       Online
# 19997     19998         163          47 2022-01-11           1       Online
# 19998     19999         593           6 2022-11-22           2       Online
# 19999     20000         170           7 2023-03-03           1  Loja Física
#
#        Valor_Total
# 0          5795.64
# ...

# %%
vendas_mensais = df_vendas.groupby(df_vendas['Data'].dt.to_period('M'))['Valor_Total'].sum()
vendas_mensais.plot(kind='line', marker='o', title="Evolução Mensal das Vendas")
plt.show()

# %%
Q1 = produtos['Preco'].quantile(0.25)
Q3 = produtos['Preco'].quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# %%
outliers = produtos[(produtos['Preco'] < limite_inferior) | (produtos['Preco'] > limite_superior)]
print(f"Produtos com preços fora do padrão: {len(outliers)}")
# Out:
# Produtos com preços fora do padrão: 0

# %%
vendas_produto = df_vendas.groupby('ID_Produto')['Valor_Total'].sum().reset_index()
base_merged = produtos.merge(vendas_produto, on='ID_Produto', how='left')
base_merged = base_merged.merge(avaliacoes.groupby('ID_Produto')['Nota'].mean().reset_index(),
                                on='ID_Produto', how='left')

sns.scatterplot(data=base_merged, x='Preco', y='Valor_Total', hue='Nota', palette='coolwarm')
plt.title("Correlação: Preço x Vendas x Nota Média")
plt.show()

base_merged[['Preco', 'Valor_Total', 'Nota']].corr()
# Out:
#                 Preco  Valor_Total      Nota
# Preco        1.000000     0.986484  0.076703
# Valor_Total  0.986484     1.000000  0.040928
# Nota         0.076703     0.040928  1.000000

# %%
sns.scatterplot(x='Tempo_Resposta', y='Nota_Satisfacao', data=atendimentos)
plt.title("Tempo de Resposta x Nota de Satisfação")
plt.show()

print(atendimentos[['Tempo_Resposta', 'Nota_Satisfacao']].corr())
# Out:
#                  Tempo_Resposta  Nota_Satisfacao
# Tempo_Resposta         1.000000        -0.011873
# Nota_Satisfacao       -0.011873         1.000000

# %%
df_vendas.loc[:,'Mes'] = df_vendas['Data'].dt.to_period('M')
canal_mensal = df_vendas.groupby(['Mes', 'Canal'])['Valor_Total'].sum().unstack()
canal_mensal.plot(kind='line', marker='o', title="Vendas Mensais por Canal")
plt.show()
# Out:
# C:\Users\ana.paschoal\AppData\Local\Temp\ipykernel_27804\1670413928.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vendas.loc[:,'Mes'] = df_vendas['Data'].dt.to_period('M')

# %%
df_vendas.to_csv("vendas_tratada.csv", index=False)
produtos.to_csv("produtos_tratados.csv", index=False)
clientes.to_csv("clientes_tratados.csv", index=False)

# %%
x = df_vendas[['Quantidade']]
y = df_vendas[['Valor_Total']]

modelo = LinearRegression()
modelo.fit(x,y)
x_pred = pd.DataFrame ({'Quantidade': [5, 6, 7, 8]})
y_pred = modelo.predict(x_pred)

plt.Figure(figsize=(8,5))
plt.scatter(x, y, color = 'green')
plt.plot(x_pred, y_pred, color = 'orange')
plt.xlabel('Quantidade vendida')
plt.ylabel('Valor Totad da Venda (R$)')
plt.title('Regrassão Linear - Quantidade x Lucro')
plt.show()

# %%
df_vendas.loc[:,'Mes'] = df_vendas['Data'].dt.month
df_vendas
# Out:
#        ID_Venda  ID_Cliente  ID_Produto       Data  Quantidade        Canal  \
# 0             1         350          45 2022-09-23           4       Online
# 1             2         925          68 2024-02-09           1  Loja Física
# 2             3         915          75 2022-09-11           4       Online
# 3             4         494          47 2024-05-10           4  Loja Física
# 4             5         523          79 2023-10-15           4  Loja Física
# ...         ...         ...         ...        ...         ...          ...
# 19995     19996         179          88 2024-04-29           1  Loja Física
# 19996     19997         702           8 2023-05-01           2       Online
# 19997     19998         163          47 2022-01-11           1       Online
# 19998     19999         593           6 2022-11-22           2       Online
# 19999     20000         170           7 2023-03-03           1  Loja Física
#
#        Valor_Total  Mes
# 0          5795.64    9
# ...

# %%
tabela_meses = df_vendas.groupby('Mes')['Valor_Total'].sum().reset_index()
tabela_meses
# Out:
#     Mes  Valor_Total
# 0     1  13809772.95
# 1     2  12783762.55
# 2     3  13813099.44
# 3     4  13615972.44
# 4     5  14046599.86
# 5     6  12998610.66
# 6     7  13655714.65
# 7     8  13307002.92
# 8     9  12588307.79
# 9    10   9671453.85
# 10   11   9795906.63
# 11   12   9437821.37

# %%
df_vendas.loc[:,'Data'] = pd.to_datetime(df_vendas['Data'], errors='coerce')
df_vendas
# Out:
#        ID_Venda  ID_Cliente  ID_Produto       Data  Quantidade        Canal  \
# 0             1         350          45 2022-09-23           4       Online
# 1             2         925          68 2024-02-09           1  Loja Física
# 2             3         915          75 2022-09-11           4       Online
# 3             4         494          47 2024-05-10           4  Loja Física
# 4             5         523          79 2023-10-15           4  Loja Física
# ...         ...         ...         ...        ...         ...          ...
# 19995     19996         179          88 2024-04-29           1  Loja Física
# 19996     19997         702           8 2023-05-01           2       Online
# 19997     19998         163          47 2022-01-11           1       Online
# 19998     19999         593           6 2022-11-22           2       Online
# 19999     20000         170           7 2023-03-03           1  Loja Física
#
#        Valor_Total      Mes
# ...

# %%
df_vendas.loc[:,'Mes'] = df_vendas['Data'].dt.to_period('M')
df_vendas
# Out:
#        ID_Venda  ID_Cliente  ID_Produto       Data  Quantidade        Canal  \
# 0             1         350          45 2022-09-23           4       Online
# 1             2         925          68 2024-02-09           1  Loja Física
# 2             3         915          75 2022-09-11           4       Online
# 3             4         494          47 2024-05-10           4  Loja Física
# 4             5         523          79 2023-10-15           4  Loja Física
# ...         ...         ...         ...        ...         ...          ...
# 19995     19996         179          88 2024-04-29           1  Loja Física
# 19996     19997         702           8 2023-05-01           2       Online
# 19997     19998         163          47 2022-01-11           1       Online
# 19998     19999         593           6 2022-11-22           2       Online
# 19999     20000         170           7 2023-03-03           1  Loja Física
#
#        Valor_Total      Mes
# ...

# %%
tabela_meses = df_vendas.groupby('Mes')['Valor_Total'].sum().reset_index()
tabela_meses
# Out:
#         Mes  Valor_Total
# 0   2022-01   4331086.37
# 1   2022-02   4021519.29
# 2   2022-03   4624177.90
# 3   2022-04   4822638.63
# 4   2022-05   4770972.61
# 5   2022-06   4591952.38
# 6   2022-07   4817193.80
# 7   2022-08   4049508.86
# 8   2022-09   4037769.87
# 9   2022-10   4911178.97
# 10  2022-11   4958551.68
# 11  2022-12   4416955.64
# 12  2023-01   4631324.05
# 13  2023-02   4267022.29
# 14  2023-03   4533498.09
# 15  2023-04   4323075.07
# 16  2023-05   4947004.16
# 17  2023-06   4210929.92
# 18  2023-07   4233383.55
# 19  2023-08   4722750.02
# 20  2023-09   4530547.05
# 21  2023-10   4760274.88
# 22  2023-11   4837354.95
# 23  2023-12   5020865.73
# 24  2024-01   4847362.53
# 25  2024-02   4495220.97
# 26  2024-03   4655423.45
# 27  2024-04   4470258.74
# 28  2024-05   4328623.09
# 29  2024-06   4195728.36
# 30  2024-07   4605137.30
# 31  2024-08   4534744.04
# 32  2024-09   4019990.87

# %%
tabela_trim_final = tabela_meses[tabela_meses['Mes'].dt.month.isin([10, 11, 12])]
tabela_trim_final
# Out:
#         Mes  Valor_Total
# 9   2022-10   4911178.97
# 10  2022-11   4958551.68
# 11  2022-12   4416955.64
# 21  2023-10   4760274.88
# 22  2023-11   4837354.95
# 23  2023-12   5020865.73

# %%
tabela_trim_final.loc[:,'Aumento_%'] = tabela_trim_final['Valor_Total'].pct_change() * 100

tabela_trim_final
# Out:
#         Mes  Valor_Total  Aumento_%
# 9   2022-10   4911178.97        NaN
# 10  2022-11   4958551.68   0.964589
# 11  2022-12   4416955.64 -10.922464
# 21  2023-10   4760274.88   7.772757
# 22  2023-11   4837354.95   1.619236
# 23  2023-12   5020865.73   3.793618

# %%
tabela_trim_final.loc[:,'Aumento_%'] = tabela_trim_final['Aumento_%'].round(2)
tabela_trim_final
# Out:
#         Mes  Valor_Total  Aumento_%
# 9   2022-10   4911178.97        NaN
# 10  2022-11   4958551.68       0.96
# 11  2022-12   4416955.64     -10.92
# 21  2023-10   4760274.88       7.77
# 22  2023-11   4837354.95       1.62
# 23  2023-12   5020865.73       3.79

# %%
df_vendas['Data'] = pd.to_datetime(df_vendas['Data'], errors='coerce')


df_vendas['Mes'] = df_vendas['Data'].dt.month


df_trim = df_vendas[df_vendas['Mes'].isin([10, 11, 12])]

sns.boxplot(x='Mes', y='Valor_Total', data=df_trim)
plt.title("Distribuição do Valor das Vendas - Meses 10, 11 e 12")
plt.xlabel("Mês")
plt.ylabel("Valor Total da Venda (R$)")
plt.show()
# Out:
# C:\Users\ana.paschoal\AppData\Local\Temp\ipykernel_27804\2473339708.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vendas['Data'] = pd.to_datetime(df_vendas['Data'], errors='coerce')
# C:\Users\ana.paschoal\AppData\Local\Temp\ipykernel_27804\2473339708.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vendas['Mes'] = df_vendas['Data'].dt.month
